# %%
import pandas as pd
import numpy as np
import datetime

# %%
import warnings

# %%
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv("seoul_coffee_ver06.csv", encoding='cp949')
df
# Out:
#           인허가일자  영업상태코드        폐업일자   소재지면적                        지번주소  \
# 0      20200713       1         0.0  329.89    서울특별시 송파구 방이동 44-3 현대토픽스
# 1      20200707       0  20200712.0     NaN       서울특별시 강남구 삼성동 159 코엑스
# 2      20200714       1         0.0  107.78      서울특별시 서초구 양재동 273-2 1층
# 3      20200714       1         0.0  367.62          서울특별시 중구 저동2가 88-5
# 4      20200714       1         0.0  130.00  서울특별시 노원구 상계동 1118-38 한올빌딩
# ...         ...     ...         ...     ...                         ...
# 47232  20100531       0  20180418.0   15.70              서울특별시송파구문정동516
# 47233  20110624       0  20140414.0   33.20              서울특별시송파구문정동292
# 47234  20110401       0  20200731.0   66.00            서울특별시송파구문정동516-0
# 47235  20190503       0  20200803.0   52.67             서울특별시용산구효창동13-2
# 47236  20120716       0  20200320.0   11.00               서울특별시종로구관철동44
#
#                       사업장명     업태구분명        long        lat  franchise
# 0              스타벅스 몽촌토성역점       커피숍  127.113106  37.516942        1.0
# 1      빈스빈스경기도미술관점(세븐스에비뉴)       커피숍  127.058819  37.512521        1.0
# 2                  이디야 포이점       커피숍  127.044560  37.475653        0.0
# 3                   투썸플레이스       커피숍  126.988639  37.564466        1.0
# 4              할리스커피 수락산역점       커피숍  127.054843  37.676224        1.0
# ...                    ...       ...         ...        ...        ...
# 47232               카페 바쿠스  기타 휴게음식점  127.124998  37.477578        2.0
# 47233            키즈카페 애플트리  기타 휴게음식점  127.119370  37.478232        2.0
# 47234         카페 0 (young)  기타 휴게음식점  127.120493  37.485106        2.0
# 47235        카페 다(Cafe DA)  기타 휴게음식점  126.963058  37.539195        2.0
# 47236           C cafe 종각점  기타 휴게음식점  126.983928  37.569397        2.0
#
# [47237 rows x 10 columns]

# %% [markdown]
# ## 폐업일자 0 으로 설정된 일자를 20211231 프로젝트 종료일자로 임의로 설정
# - 향후 (폐업일-인허가일자)영업일 계산으로 분류를 하기위한 목적
# - 2년 이상/이하를 기준으로 영업중인 카페와 폐업한 카페로 총 4 단계로 분류하기 위함.

# %%
for i in (df[df['폐업일자'] == 0]).index:
    df.loc[i, '폐업일자'] = 20211231
df
# Out:
#           인허가일자  영업상태코드        폐업일자   소재지면적                        지번주소  \
# 0      20200713       1  20211231.0  329.89    서울특별시 송파구 방이동 44-3 현대토픽스
# 1      20200707       0  20200712.0     NaN       서울특별시 강남구 삼성동 159 코엑스
# 2      20200714       1  20211231.0  107.78      서울특별시 서초구 양재동 273-2 1층
# 3      20200714       1  20211231.0  367.62          서울특별시 중구 저동2가 88-5
# 4      20200714       1  20211231.0  130.00  서울특별시 노원구 상계동 1118-38 한올빌딩
# ...         ...     ...         ...     ...                         ...
# 47232  20100531       0  20180418.0   15.70              서울특별시송파구문정동516
# 47233  20110624       0  20140414.0   33.20              서울특별시송파구문정동292
# 47234  20110401       0  20200731.0   66.00            서울특별시송파구문정동516-0
# 47235  20190503       0  20200803.0   52.67             서울특별시용산구효창동13-2
# 47236  20120716       0  20200320.0   11.00               서울특별시종로구관철동44
#
#                       사업장명     업태구분명        long        lat  franchise
# 0              스타벅스 몽촌토성역점       커피숍  127.113106  37.516942        1.0
# 1      빈스빈스경기도미술관점(세븐스에비뉴)       커피숍  127.058819  37.512521        1.0
# 2                  이디야 포이점       커피숍  127.044560  37.475653        0.0
# 3                   투썸플레이스       커피숍  126.988639  37.564466        1.0
# 4              할리스커피 수락산역점       커피숍  127.054843  37.676224        1.0
# ...                    ...       ...         ...        ...        ...
# 47232               카페 바쿠스  기타 휴게음식점  127.124998  37.477578        2.0
# 47233            키즈카페 애플트리  기타 휴게음식점  127.119370  37.478232        2.0
# 47234         카페 0 (young)  기타 휴게음식점  127.120493  37.485106        2.0
# 47235        카페 다(Cafe DA)  기타 휴게음식점  126.963058  37.539195        2.0
# 47236           C cafe 종각점  기타 휴게음식점  126.983928  37.569397        2.0
#
# [47237 rows x 10 columns]

# %%
df['폐업일자'] = df['폐업일자'].astype(int)

# %%
df1 = df.copy()

# %%
df1.drop(['소재지면적','지번주소','업태구분명'],  axis=1, inplace=True)
df1
# Out:
#           인허가일자  영업상태코드      폐업일자                 사업장명        long        lat  \
# 0      20200713       1  20211231          스타벅스 몽촌토성역점  127.113106  37.516942
# 1      20200707       0  20200712  빈스빈스경기도미술관점(세븐스에비뉴)  127.058819  37.512521
# 2      20200714       1  20211231              이디야 포이점  127.044560  37.475653
# 3      20200714       1  20211231               투썸플레이스  126.988639  37.564466
# 4      20200714       1  20211231          할리스커피 수락산역점  127.054843  37.676224
# ...         ...     ...       ...                  ...         ...        ...
# 47232  20100531       0  20180418               카페 바쿠스  127.124998  37.477578
# 47233  20110624       0  20140414            키즈카페 애플트리  127.119370  37.478232
# 47234  20110401       0  20200731         카페 0 (young)  127.120493  37.485106
# 47235  20190503       0  20200803        카페 다(Cafe DA)  126.963058  37.539195
# 47236  20120716       0  20200320           C cafe 종각점  126.983928  37.569397
#
#        franchise
# 0            1.0
# 1            1.0
# 2            0.0
# 3            1.0
# 4            1.0
# ...          ...
# 47232        2.0
# 47233        2.0
# 47234        2.0
# 47235        2.0
# 47236        2.0
#
# [47237 rows x 7 columns]

# %%
df1['폐업일자'].sort_values()
# Out:
# 28301    11111111
# 37684    13300310
# 38008    18991230
# 40121    18991230
# 40884    18991230
#            ...
# 17918    20211231
# 17917    20211231
# 17916    20211231
# 17932    20211231
# 0        20211231
# Name: 폐업일자, Length: 47237, dtype: int32

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47237 entries, 0 to 47236
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   인허가일자      47237 non-null  int64
#  1   영업상태코드     47237 non-null  int64
#  2   폐업일자       47237 non-null  int32
#  3   사업장명       47237 non-null  object
#  4   long       47237 non-null  float64
#  5   lat        47237 non-null  float64
#  6   franchise  47237 non-null  float64
# dtypes: float64(3), int32(1), int64(2), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# ## 시계열에 표현할 1980년 이후의 데이터만 뽑아내고 이전 데이터는 삭제

# %%
df2 = df1[df1['인허가일자'] >= 19800000]
df2
# Out:
#           인허가일자  영업상태코드      폐업일자                 사업장명        long        lat  \
# 0      20200713       1  20211231          스타벅스 몽촌토성역점  127.113106  37.516942
# 1      20200707       0  20200712  빈스빈스경기도미술관점(세븐스에비뉴)  127.058819  37.512521
# 2      20200714       1  20211231              이디야 포이점  127.044560  37.475653
# 3      20200714       1  20211231               투썸플레이스  126.988639  37.564466
# 4      20200714       1  20211231          할리스커피 수락산역점  127.054843  37.676224
# ...         ...     ...       ...                  ...         ...        ...
# 47232  20100531       0  20180418               카페 바쿠스  127.124998  37.477578
# 47233  20110624       0  20140414            키즈카페 애플트리  127.119370  37.478232
# 47234  20110401       0  20200731         카페 0 (young)  127.120493  37.485106
# 47235  20190503       0  20200803        카페 다(Cafe DA)  126.963058  37.539195
# 47236  20120716       0  20200320           C cafe 종각점  126.983928  37.569397
#
#        franchise
# 0            1.0
# 1            1.0
# 2            0.0
# 3            1.0
# 4            1.0
# ...          ...
# 47232        2.0
# 47233        2.0
# 47234        2.0
# 47235        2.0
# 47236        2.0
#
# [45786 rows x 7 columns]

# %%
df2['폐업일자'].sort_values()
# Out:
# 28301    11111111
# 37684    13300310
# 41127    18991230
# 38379    18991230
# 39877    18991230
#            ...
# 17587    20211231
# 17585    20211231
# 17584    20211231
# 17606    20211231
# 0        20211231
# Name: 폐업일자, Length: 45786, dtype: int32

# %%
df3 = df2[df2['폐업일자'] >= 19800000]
df3
# Out:
#           인허가일자  영업상태코드      폐업일자                 사업장명        long        lat  \
# 0      20200713       1  20211231          스타벅스 몽촌토성역점  127.113106  37.516942
# 1      20200707       0  20200712  빈스빈스경기도미술관점(세븐스에비뉴)  127.058819  37.512521
# 2      20200714       1  20211231              이디야 포이점  127.044560  37.475653
# 3      20200714       1  20211231               투썸플레이스  126.988639  37.564466
# 4      20200714       1  20211231          할리스커피 수락산역점  127.054843  37.676224
# ...         ...     ...       ...                  ...         ...        ...
# 47232  20100531       0  20180418               카페 바쿠스  127.124998  37.477578
# 47233  20110624       0  20140414            키즈카페 애플트리  127.119370  37.478232
# 47234  20110401       0  20200731         카페 0 (young)  127.120493  37.485106
# 47235  20190503       0  20200803        카페 다(Cafe DA)  126.963058  37.539195
# 47236  20120716       0  20200320           C cafe 종각점  126.983928  37.569397
#
#        franchise
# 0            1.0
# 1            1.0
# 2            0.0
# 3            1.0
# 4            1.0
# ...          ...
# 47232        2.0
# 47233        2.0
# 47234        2.0
# 47235        2.0
# 47236        2.0
#
# [45747 rows x 7 columns]

# %% [markdown]
# ## (인허가일자, 폐업일자) datetime 형태로 format 변경
# - 그래프에 표현하기 위해 날짜 전처리 작업
# - 필요하는 않은 컬럼에 대한 삭제

# %%
df3['인허가일자'] = pd.to_datetime(df3['인허가일자'], format='%Y%m%d')
df3['폐업일자'] = pd.to_datetime(df3['폐업일자'], format='%Y%m%d')
df3
# Out:
#            인허가일자  영업상태코드       폐업일자                 사업장명        long  \
# 0     2020-07-13       1 2021-12-31          스타벅스 몽촌토성역점  127.113106
# 1     2020-07-07       0 2020-07-12  빈스빈스경기도미술관점(세븐스에비뉴)  127.058819
# 2     2020-07-14       1 2021-12-31              이디야 포이점  127.044560
# 3     2020-07-14       1 2021-12-31               투썸플레이스  126.988639
# 4     2020-07-14       1 2021-12-31          할리스커피 수락산역점  127.054843
# ...          ...     ...        ...                  ...         ...
# 47232 2010-05-31       0 2018-04-18               카페 바쿠스  127.124998
# 47233 2011-06-24       0 2014-04-14            키즈카페 애플트리  127.119370
# 47234 2011-04-01       0 2020-07-31         카페 0 (young)  127.120493
# 47235 2019-05-03       0 2020-08-03        카페 다(Cafe DA)  126.963058
# 47236 2012-07-16       0 2020-03-20           C cafe 종각점  126.983928
#
#              lat  franchise
# 0      37.516942        1.0
# 1      37.512521        1.0
# 2      37.475653        0.0
# 3      37.564466        1.0
# 4      37.676224        1.0
# ...          ...        ...
# 47232  37.477578        2.0
# 47233  37.478232        2.0
# 47234  37.485106        2.0
# 47235  37.539195        2.0
# 47236  37.569397        2.0
#
# [45747 rows x 7 columns]

# %%
df3['in_month']=df3['인허가일자'].dt.month
df3['in_year']=df3['인허가일자'].dt.year
df3['out_month']=df3['폐업일자'].dt.month
df3['out_year']=df3['폐업일자'].dt.year
df3
# Out:
#            인허가일자  영업상태코드       폐업일자                 사업장명        long  \
# 0     2020-07-13       1 2021-12-31          스타벅스 몽촌토성역점  127.113106
# 1     2020-07-07       0 2020-07-12  빈스빈스경기도미술관점(세븐스에비뉴)  127.058819
# 2     2020-07-14       1 2021-12-31              이디야 포이점  127.044560
# 3     2020-07-14       1 2021-12-31               투썸플레이스  126.988639
# 4     2020-07-14       1 2021-12-31          할리스커피 수락산역점  127.054843
# ...          ...     ...        ...                  ...         ...
# 47232 2010-05-31       0 2018-04-18               카페 바쿠스  127.124998
# 47233 2011-06-24       0 2014-04-14            키즈카페 애플트리  127.119370
# 47234 2011-04-01       0 2020-07-31         카페 0 (young)  127.120493
# 47235 2019-05-03       0 2020-08-03        카페 다(Cafe DA)  126.963058
# 47236 2012-07-16       0 2020-03-20           C cafe 종각점  126.983928
#
#              lat  franchise  in_month  in_year  out_month  out_year
# 0      37.516942        1.0         7     2020         12      2021
# 1      37.512521        1.0         7     2020          7      2020
# 2      37.475653        0.0         7     2020         12      2021
# 3      37.564466        1.0         7     2020         12      2021
# 4      37.676224        1.0         7     2020         12      2021
# ...          ...        ...       ...      ...        ...       ...
# 47232  37.477578        2.0         5     2010          4      2018
# 47233  37.478232        2.0         6     2011          4      2014
# 47234  37.485106        2.0         4     2011          7      2020
# 47235  37.539195        2.0         5     2019          8      2020
# 47236  37.569397        2.0         7     2012          3      2020
#
# [45747 rows x 11 columns]

# %%
df3['in_count'] = 1
df3['out_count'] = 1
df3
# Out:
#            인허가일자  영업상태코드       폐업일자                 사업장명        long  \
# 0     2020-07-13       1 2021-12-31          스타벅스 몽촌토성역점  127.113106
# 1     2020-07-07       0 2020-07-12  빈스빈스경기도미술관점(세븐스에비뉴)  127.058819
# 2     2020-07-14       1 2021-12-31              이디야 포이점  127.044560
# 3     2020-07-14       1 2021-12-31               투썸플레이스  126.988639
# 4     2020-07-14       1 2021-12-31          할리스커피 수락산역점  127.054843
# ...          ...     ...        ...                  ...         ...
# 47232 2010-05-31       0 2018-04-18               카페 바쿠스  127.124998
# 47233 2011-06-24       0 2014-04-14            키즈카페 애플트리  127.119370
# 47234 2011-04-01       0 2020-07-31         카페 0 (young)  127.120493
# 47235 2019-05-03       0 2020-08-03        카페 다(Cafe DA)  126.963058
# 47236 2012-07-16       0 2020-03-20           C cafe 종각점  126.983928
#
#              lat  franchise  in_month  in_year  out_month  out_year  in_count  \
# 0      37.516942        1.0         7     2020         12      2021         1
# 1      37.512521        1.0         7     2020          7      2020         1
# 2      37.475653        0.0         7     2020         12      2021         1
# 3      37.564466        1.0         7     2020         12      2021         1
# 4      37.676224        1.0         7     2020         12      2021         1
# ...          ...        ...       ...      ...        ...       ...       ...
# 47232  37.477578        2.0         5     2010          4      2018         1
# 47233  37.478232        2.0         6     2011          4      2014         1
# 47234  37.485106        2.0         4     2011          7      2020         1
# 47235  37.539195        2.0         5     2019          8      2020         1
# 47236  37.569397        2.0         7     2012          3      2020         1
#
#        out_count
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 47232          1
# 47233          1
# 47234          1
# 47235          1
# 47236          1
#
# [45747 rows x 13 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45747 entries, 0 to 47236
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   인허가일자      45747 non-null  datetime64[ns]
#  1   영업상태코드     45747 non-null  int64
#  2   폐업일자       45747 non-null  datetime64[ns]
#  3   사업장명       45747 non-null  object
#  4   long       45747 non-null  float64
#  5   lat        45747 non-null  float64
#  6   franchise  45747 non-null  float64
#  7   in_month   45747 non-null  int64
#  8   in_year    45747 non-null  int64
#  9   out_month  45747 non-null  int64
#  10  out_year   45747 non-null  int64
#  11  in_count   45747 non-null  int64
#  12  out_count  45747 non-null  int64
# dtypes: datetime64[ns](2), float64(3), int64(7), object(1)
# memory usage: 4.9+ MB

# %%
df3.drop(['인허가일자','영업상태코드','폐업일자','사업장명','long','lat','franchise'], axis=1, inplace=True)
df3
# Out:
#        in_month  in_year  out_month  out_year  in_count  out_count
# 0             7     2020         12      2021         1          1
# 1             7     2020          7      2020         1          1
# 2             7     2020         12      2021         1          1
# 3             7     2020         12      2021         1          1
# 4             7     2020         12      2021         1          1
# ...         ...      ...        ...       ...       ...        ...
# 47232         5     2010          4      2018         1          1
# 47233         6     2011          4      2014         1          1
# 47234         4     2011          7      2020         1          1
# 47235         5     2019          8      2020         1          1
# 47236         7     2012          3      2020         1          1
#
# [45747 rows x 6 columns]

# %%
df_in = df3.groupby(['in_year', 'in_month'])['in_count'].sum()
df_out = df3.groupby(['out_year', 'out_month'])['out_count'].sum()

# %%
df_in
# Out:
# in_year  in_month
# 1980     1            14
#          2            14
#          3            12
#          4            26
#          5            16
#                     ...
# 2021     8           256
#          9           194
#          10          225
#          11          212
#          12           45
# Name: in_count, Length: 504, dtype: int64

# %%
df_out
# Out:
# out_year  out_month
# 1980      2                1
#           6                1
#           8                1
# 1981      4                1
#           7                1
#                        ...
# 2021      8              139
#           9              143
#           10             167
#           11             137
#           12           15914
# Name: out_count, Length: 433, dtype: int64

# %%
df4 = pd.DataFrame(df_in)
df5 = pd.DataFrame(df_out)
df = pd.concat([df4, df5], axis=1)
df
# Out:
#          in_count  out_count
# 1980 1         14        NaN
#      2         14        1.0
#      3         12        NaN
#      4         26        NaN
#      5         16        NaN
# ...           ...        ...
# 2021 8        256      139.0
#      9        194      143.0
#      10       225      167.0
#      11       212      137.0
#      12        45    15914.0
#
# [504 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 504 entries, (1980, 1) to (2021, 12)
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   in_count   504 non-null    int64
#  1   out_count  433 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 10.7 KB

# %%
df.to_csv('seoul_coffee_time.csv', index=True, encoding='cp949')

# %%
df = pd.read_csv("seoul_coffee_time.csv", encoding='cp949')
df
# Out:
#      Unnamed: 0  Unnamed: 1  in_count  out_count
# 0          1980           1        14        NaN
# 1          1980           2        14        1.0
# 2          1980           3        12        NaN
# 3          1980           4        26        NaN
# 4          1980           5        16        NaN
# ..          ...         ...       ...        ...
# 499        2021           8       256      139.0
# 500        2021           9       194      143.0
# 501        2021          10       225      167.0
# 502        2021          11       212      137.0
# 503        2021          12        45    15914.0
#
# [504 rows x 4 columns]

# %%
df.rename(columns = {"Unnamed: 0": "year","Unnamed: 1": "month"}, inplace = True)
df
# Out:
#      year  month  in_count  out_count
# 0    1980      1        14        NaN
# 1    1980      2        14        1.0
# 2    1980      3        12        NaN
# 3    1980      4        26        NaN
# 4    1980      5        16        NaN
# ..    ...    ...       ...        ...
# 499  2021      8       256      139.0
# 500  2021      9       194      143.0
# 501  2021     10       225      167.0
# 502  2021     11       212      137.0
# 503  2021     12        45    15914.0
#
# [504 rows x 4 columns]

# %%
df['date']=df.year.apply(str) + '_'+ df.month.apply(str)
df
# Out:
#      year  month  in_count  out_count     date
# 0    1980      1        14        NaN   1980_1
# 1    1980      2        14        1.0   1980_2
# 2    1980      3        12        NaN   1980_3
# 3    1980      4        26        NaN   1980_4
# 4    1980      5        16        NaN   1980_5
# ..    ...    ...       ...        ...      ...
# 499  2021      8       256      139.0   2021_8
# 500  2021      9       194      143.0   2021_9
# 501  2021     10       225      167.0  2021_10
# 502  2021     11       212      137.0  2021_11
# 503  2021     12        45    15914.0  2021_12
#
# [504 rows x 5 columns]

# %%
df_index = df[df['date'] == '2021_12'].index
df_index
# Out:
# Int64Index([503], dtype='int64')

# %%
df = df.drop(index=df_index)
df
# Out:
#      year  month  in_count  out_count     date
# 0    1980      1        14        NaN   1980_1
# 1    1980      2        14        1.0   1980_2
# 2    1980      3        12        NaN   1980_3
# 3    1980      4        26        NaN   1980_4
# 4    1980      5        16        NaN   1980_5
# ..    ...    ...       ...        ...      ...
# 498  2021      7       240      179.0   2021_7
# 499  2021      8       256      139.0   2021_8
# 500  2021      9       194      143.0   2021_9
# 501  2021     10       225      167.0  2021_10
# 502  2021     11       212      137.0  2021_11
#
# [503 rows x 5 columns]

# %%
df.to_csv('seoul_coffee_time_month.csv', index=False, encoding='cp949')

# %% [markdown]
# ## 월 단위로 오픈, 폐업 한 카페 수 그래프 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %% [markdown]
# ### 오픈한 카페 수(월 단위)

# %%
fig = plt.figure(figsize=(20,5))
plt.plot(df.date, df['in_count'])
plt.xlabel('년월')
plt.ylabel('매장 수')
plt.show()

# %% [markdown]
# ### 폐업한 카페 수 (월 단위)

# %%
fig = plt.figure(figsize=(20,5))
plt.plot(df.date, df['out_count'])
plt.xlabel('년월')
plt.ylabel('매장 수')
plt.show()

# %%
df_in = df.groupby(['year'])['in_count'].sum()
df_out = df.groupby(['year'])['out_count'].sum()

# %%
df2 = pd.DataFrame(df_in)
df3 = pd.DataFrame(df_out)
df4 = pd.concat([df2, df3], axis=1)
df4
# Out:
#       in_count  out_count
# year
# 1980       226        3.0
# 1981       579        2.0
# 1982       546        2.0
# 1983       599        2.0
# 1984       679        3.0
# 1985       633        2.0
# 1986       637        6.0
# 1987       517        9.0
# 1988       525       32.0
# 1989       472      154.0
# 1990       384      231.0
# 1991       518      316.0
# 1992       795      394.0
# 1993      1799      412.0
# 1994      1147      934.0
# 1995       683     1112.0
# 1996       584     1082.0
# 1997       513     1149.0
# 1998       407      930.0
# 1999       488     1004.0
# 2000       484      988.0
# 2001       589      694.0
# 2002       583      695.0
# 2003       414      618.0
# 2004       332      570.0
# 2005       352      527.0
# 2006       441      472.0
# 2007       564      469.0
# 2008       658      531.0
# 2009      1006      489.0
# 2010      1549      573.0
# 2011      1867      681.0
# 2012      1812      708.0
# 2013      1901      817.0
# 2014      2336      968.0
# 2015      2282     1320.0
# 2016      2617     1595.0
# 2017      2625     1803.0
# 2018      2771     1940.0
# 2019      2747     1904.0
# 2020      2484     1873.0
# 2021      2557     1819.0

# %% [markdown]
# ### 오픈한 카페 수 (년 단위)

# %%
fig = plt.figure(figsize=(20,5))
plt.plot(df4.index, df4['in_count'])
plt.xlabel('년월')
plt.ylabel('오픈 매장수')
plt.show()

# %% [markdown]
# ### 폐업한 카페 수 (년 단위)

# %%
fig = plt.figure(figsize=(20,5))
plt.plot(df4.index, df4['out_count'])
plt.xlabel('년월')
plt.ylabel('폐업 매장수')
plt.show()

# %% [markdown]
# ### 오픈/폐업한 매장수 (년 단위)

# %%
fig = plt.figure(figsize=(12,5))
plt.plot(df4.index, df4['in_count'])
plt.plot(df4.index, df4['out_count'])
plt.xlabel('년월')
plt.ylabel('오픈 매장수')
plt.legend(['오픈매장','폐업매장'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\TS17EF~1.SBY\AppData\Local\Temp/ipykernel_3156/2160558370.py in <module>
# ----> 1 fig = plt.figure(figsize=(12,5))
#       2 plt.plot(df4.index, df4['in_count'])
#       3 plt.plot(df4.index, df4['out_count'])
#       4 plt.xlabel('년월')
#       5 plt.ylabel('오픈 매장수')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## 향후 3년 카페 오픈/폐업에 대한 시계열 예측
# - 데이터 전처리(년 단위/월 단위)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 1980 to 2021
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   in_count   42 non-null     int64
#  1   out_count  42 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1008.0 bytes

# %%
df = df4.copy()
df.head()
# Out:
#       in_count  out_count
# year
# 1980       226        3.0
# 1981       579        2.0
# 1982       546        2.0
# 1983       599        2.0
# 1984       679        3.0

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       42 non-null     int64
#  1   in_count   42 non-null     int64
#  2   out_count  42 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 1.1 KB

# %%
df['month'] = 12
df['day'] = 31

# %%
df.head()
# Out:
#    year  in_count  out_count  month  day
# 0  1980       226        3.0     12   31
# 1  1981       579        2.0     12   31
# 2  1982       546        2.0     12   31
# 3  1983       599        2.0     12   31
# 4  1984       679        3.0     12   31

# %%
re_date = df[df['year'] == 2021]

# %%
re_date.month = 11
re_date.day = 30

# %%
df[df['year'] == 2021] = re_date
df
# Out:
#     year  in_count  out_count  month  day
# 0   1980       226        3.0     12   31
# 1   1981       579        2.0     12   31
# 2   1982       546        2.0     12   31
# 3   1983       599        2.0     12   31
# 4   1984       679        3.0     12   31
# 5   1985       633        2.0     12   31
# 6   1986       637        6.0     12   31
# 7   1987       517        9.0     12   31
# 8   1988       525       32.0     12   31
# 9   1989       472      154.0     12   31
# 10  1990       384      231.0     12   31
# 11  1991       518      316.0     12   31
# 12  1992       795      394.0     12   31
# 13  1993      1799      412.0     12   31
# 14  1994      1147      934.0     12   31
# 15  1995       683     1112.0     12   31
# 16  1996       584     1082.0     12   31
# 17  1997       513     1149.0     12   31
# 18  1998       407      930.0     12   31
# 19  1999       488     1004.0     12   31
# 20  2000       484      988.0     12   31
# 21  2001       589      694.0     12   31
# 22  2002       583      695.0     12   31
# 23  2003       414      618.0     12   31
# 24  2004       332      570.0     12   31
# 25  2005       352      527.0     12   31
# 26  2006       441      472.0     12   31
# 27  2007       564      469.0     12   31
# 28  2008       658      531.0     12   31
# 29  2009      1006      489.0     12   31
# 30  2010      1549      573.0     12   31
# 31  2011      1867      681.0     12   31
# 32  2012      1812      708.0     12   31
# 33  2013      1901      817.0     12   31
# 34  2014      2336      968.0     12   31
# 35  2015      2282     1320.0     12   31
# 36  2016      2617     1595.0     12   31
# 37  2017      2625     1803.0     12   31
# 38  2018      2771     1940.0     12   31
# 39  2019      2747     1904.0     12   31
# 40  2020      2484     1873.0     12   31
# 41  2021      2557     1819.0     11   30

# %%
cols = ['year','month','day']
df['date'] =df[cols].apply(lambda x: ''.join(x.values.astype(str)), axis=1)
df
# Out:
#     year  in_count  out_count  month  day      date
# 0   1980       226        3.0     12   31  19801231
# 1   1981       579        2.0     12   31  19811231
# 2   1982       546        2.0     12   31  19821231
# 3   1983       599        2.0     12   31  19831231
# 4   1984       679        3.0     12   31  19841231
# 5   1985       633        2.0     12   31  19851231
# 6   1986       637        6.0     12   31  19861231
# 7   1987       517        9.0     12   31  19871231
# 8   1988       525       32.0     12   31  19881231
# 9   1989       472      154.0     12   31  19891231
# 10  1990       384      231.0     12   31  19901231
# 11  1991       518      316.0     12   31  19911231
# 12  1992       795      394.0     12   31  19921231
# 13  1993      1799      412.0     12   31  19931231
# 14  1994      1147      934.0     12   31  19941231
# 15  1995       683     1112.0     12   31  19951231
# 16  1996       584     1082.0     12   31  19961231
# 17  1997       513     1149.0     12   31  19971231
# 18  1998       407      930.0     12   31  19981231
# 19  1999       488     1004.0     12   31  19991231
# 20  2000       484      988.0     12   31  20001231
# 21  2001       589      694.0     12   31  20011231
# 22  2002       583      695.0     12   31  20021231
# 23  2003       414      618.0     12   31  20031231
# 24  2004       332      570.0     12   31  20041231
# 25  2005       352      527.0     12   31  20051231
# 26  2006       441      472.0     12   31  20061231
# 27  2007       564      469.0     12   31  20071231
# 28  2008       658      531.0     12   31  20081231
# 29  2009      1006      489.0     12   31  20091231
# 30  2010      1549      573.0     12   31  20101231
# 31  2011      1867      681.0     12   31  20111231
# 32  2012      1812      708.0     12   31  20121231
# 33  2013      1901      817.0     12   31  20131231
# 34  2014      2336      968.0     12   31  20141231
# 35  2015      2282     1320.0     12   31  20151231
# 36  2016      2617     1595.0     12   31  20161231
# 37  2017      2625     1803.0     12   31  20171231
# 38  2018      2771     1940.0     12   31  20181231
# 39  2019      2747     1904.0     12   31  20191231
# 40  2020      2484     1873.0     12   31  20201231
# 41  2021      2557     1819.0     11   30  20211130

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')
df
# Out:
#     year  in_count  out_count  month  day       date
# 0   1980       226        3.0     12   31 1980-12-31
# 1   1981       579        2.0     12   31 1981-12-31
# 2   1982       546        2.0     12   31 1982-12-31
# 3   1983       599        2.0     12   31 1983-12-31
# 4   1984       679        3.0     12   31 1984-12-31
# 5   1985       633        2.0     12   31 1985-12-31
# 6   1986       637        6.0     12   31 1986-12-31
# 7   1987       517        9.0     12   31 1987-12-31
# 8   1988       525       32.0     12   31 1988-12-31
# 9   1989       472      154.0     12   31 1989-12-31
# 10  1990       384      231.0     12   31 1990-12-31
# 11  1991       518      316.0     12   31 1991-12-31
# 12  1992       795      394.0     12   31 1992-12-31
# 13  1993      1799      412.0     12   31 1993-12-31
# 14  1994      1147      934.0     12   31 1994-12-31
# 15  1995       683     1112.0     12   31 1995-12-31
# 16  1996       584     1082.0     12   31 1996-12-31
# 17  1997       513     1149.0     12   31 1997-12-31
# 18  1998       407      930.0     12   31 1998-12-31
# 19  1999       488     1004.0     12   31 1999-12-31
# 20  2000       484      988.0     12   31 2000-12-31
# 21  2001       589      694.0     12   31 2001-12-31
# 22  2002       583      695.0     12   31 2002-12-31
# 23  2003       414      618.0     12   31 2003-12-31
# 24  2004       332      570.0     12   31 2004-12-31
# 25  2005       352      527.0     12   31 2005-12-31
# 26  2006       441      472.0     12   31 2006-12-31
# 27  2007       564      469.0     12   31 2007-12-31
# 28  2008       658      531.0     12   31 2008-12-31
# 29  2009      1006      489.0     12   31 2009-12-31
# 30  2010      1549      573.0     12   31 2010-12-31
# 31  2011      1867      681.0     12   31 2011-12-31
# 32  2012      1812      708.0     12   31 2012-12-31
# 33  2013      1901      817.0     12   31 2013-12-31
# 34  2014      2336      968.0     12   31 2014-12-31
# 35  2015      2282     1320.0     12   31 2015-12-31
# 36  2016      2617     1595.0     12   31 2016-12-31
# 37  2017      2625     1803.0     12   31 2017-12-31
# 38  2018      2771     1940.0     12   31 2018-12-31
# 39  2019      2747     1904.0     12   31 2019-12-31
# 40  2020      2484     1873.0     12   31 2020-12-31
# 41  2021      2557     1819.0     11   30 2021-11-30

# %%
df.drop(['year','month','day'], axis=1, inplace=True)

# %%
df.to_csv('seoul_coffee_time_year.csv', index=False, encoding='cp949')

# %%
df_in = df.copy()
df_out = df.copy()

# %%
df_in.drop(['out_count'], axis=1, inplace=True)
df_out.drop(['in_count'], axis=1, inplace=True)

# %%
df_in = df_in.set_index(['date'])
df_out = df_out.set_index(['date'])

# %%
# df_in.plot_diagnostics(fig_size=(16,10))

# %%
df_in.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### 오픈매장수 예측 (년 단위)

# %%
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm
import itertools

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and d triplets
seasonal_pdq = [ (x[0], x[1], x[2], 12)  for x in pdq ]

print('Example of parameter combinations for Seasonal ARIMA ...')
print('SARIMAX:  {} x {}'.format(pdq[1], seasonal_pdq[1]) )
print('SARIMAX:  {} x {}'.format(pdq[1], seasonal_pdq[2]) )
print('SARIMAX:  {} x {}'.format(pdq[2], seasonal_pdq[3]) )
print('SARIMAX:  {} x {}'.format(pdq[2], seasonal_pdq[4]) )
# Out:
# Example of parameter combinations for Seasonal ARIMA ...
# SARIMAX:  (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX:  (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX:  (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX:  (0, 1, 0) x (1, 0, 0, 12)

# %%
select_candi = 10000000
param_candi = ( 0, 0, 0 )
param_seasonal_candi = ( 0, 0, 0)

count=0
end_count = len(pdq)

for param in pdq:   
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX( df_in['in_count'],
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False
                                           )
            results = mod.fit()
            count += 1
            if count <= 5:
                print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            
            if results.aic < select_candi:
                select_candi = results.aic
                param_candi = param
                param_seasonal_candi = param_seasonal
        except:
            continue
            
print(param_candi, param_seasonal_candi, select_candi)
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:711.420931539067
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1325.7060302507016
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:497.4598330118606
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:301.81547407127545
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:512.0845407915455
# (1, 1, 1) (0, 1, 1, 12) 214.86970848975565

# %%
mod = sm.tsa.statespace.SARIMAX(
    df_in['in_count'],
    order=(1, 1, 1),
    seasonal_order=(0, 1, 1, 12),
    enforce_stationarity=False,
    enforce_invertibility=False
)

results = mod.fit()

print(results.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                           in_count   No. Observations:                   42
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 12)   Log Likelihood                -103.435
# Date:                            Fri, 24 Dec 2021   AIC                            214.870
# Time:                                    15:50:45   BIC                            217.702
# Sample:                                         0   HQIC                           214.840
#                                              - 42
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5216      0.387      1.347      0.178      -0.237       1.280
# ma.L1          0.1299      0.394      0.330      0.742      -0.642       0.902
# ma.S.L12       0.0970      0.311      0.312      0.755      -0.513       0.707
# sigma2      5.715e+04   3.16e+04      1.808      0.071   -4788.420    1.19e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 2.19
# Prob(Q):                              0.70   Prob(JB):                         0.33
# Heteroskedasticity (H):               0.47   Skew:                             0.79
# Prob(H) (two-sided):                  0.43   Kurtosis:                         2.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# results.plot_diagnostics()
# results.plot_diagnostics(fig_size=(16,10))

# %% [markdown]
# ### get_prediction(dynamic=False)

# %%
pred = results.get_prediction(
    start=pd.to_datetime('2015-12-31'),
    dynamic=False
)

pred_ci = pred.conf_int()

# %%
# 관측 데이터  1980년 부터 끝까지 
ax = df_in['in_count']['1980' : ].plot( label='observed', figsize=(12, 8) )

# 예측
pred.predicted_mean.plot(
    ax=ax,
    label='One-step ahead Forecast',
    alpha=.7
)

ax.fill_between(
    pred_ci.index,
    pred_ci['lower in_count'],
    pred_ci['upper in_count'],
    color='k',
    alpha=.2
)

ax.set_xlabel('Date')
ax.set_ylabel('Count')
plt.legend(loc=5)

plt.show()

# %% [markdown]
# ### get_prediction(dynamic=True)

# %%
y_forecasted = pred.predicted_mean
y_truth = df_in['in_count']['1980-12-31' : ]

# Compute the Mean Square Error
mse = (( y_forecasted - y_truth ) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format( round(mse, 2) ) )
# Out:
# The Mean Squared Error of our forecasts is 46155.89

# %%
pred_dynamic = results.get_prediction(
    start=pd.to_datetime('2015-12-31'),
    dynamic=True,
    full_results=True
)

pred_dynamic_ci = pred_dynamic.conf_int()

# %%
pred_dynamic

# %%
# 관측 데이터  1980년 부터 끝까지 
ax = df_in['in_count']['1980' : ].plot( label='observed', figsize=(12, 8) )

# 예측
pred_dynamic.predicted_mean.plot(
    ax=ax,
    label='Dynamic Forcast'
)

ax.fill_between(
    pred_ci.index,
    pred_ci['lower in_count'],
    pred_ci['upper in_count'],
    color='k',
    alpha=.2
)

ax.fill_betweenx(
    ax.get_ylim(),
    pd.to_datetime('2015-12-31'),
    df.index[-1],
    alpha=.2
)

ax.set_xlabel('Date')
ax.set_ylabel('Count')
plt.legend(loc=9)

plt.show()

# %% [markdown]
# ### get_forecast(step=5)

# %%
# Extract the predicted and true values of our time series
y_forecasted = pred_dynamic.predicted_mean
y_truth = df_in['in_count']['2021-11-30' : ]

# Compute the Mean Square Error
mse = (( y_forecasted - y_truth ) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format( round(mse, 2) ) )
# Out:
# The Mean Squared Error of our forecasts is 706127.23

# %%
# Get forecast some steps ahead in future
pred_uc = results.get_forecast(steps=5 )

# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

# %%
pred_uc

# %%
# 관측 데이터  1980년 부터 끝까지 
ax = df_in['in_count']['1980' : ].plot( label='observed', figsize=(12, 8) )

# 예측
pred_uc.predicted_mean.plot(
    ax=ax,
    label='Forcast'
)

ax.fill_between(
    pred_ci.index,
    pred_ci['lower in_count'],
    pred_ci['upper in_count'],
    color='k',
    alpha=.2
)


ax.set_xlabel('Date')
ax.set_ylabel('Count')
plt.legend(loc=9)

plt.show()

# %%
pred_ci
# Out:
#     lower in_count  upper in_count
# 42     2519.314097     3456.421300
# 43     2330.507762     4139.747050
# 44     1827.812402     4426.956936
# 45     1538.736398     4838.006658
# 46     1691.839913     5612.857878

# %% [markdown]
# ### 폐업 SARIMAX (년 단위)

# %%
select_candi = 10000000
param_candi = ( 0, 0, 0 )
param_seasonal_candi = ( 0, 0, 0)

count=0
end_count = len(pdq)

for param in pdq:   
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX( df_out['out_count'],
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=True,
                                            enforce_invertibility=True
                                           )
            results = mod.fit()
            count += 1
            if count <= 5:
                print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            
            if results.aic < select_candi:
                select_candi = results.aic
                param_candi = param
                param_seasonal_candi = param_seasonal
        except:
            continue
            
print(param_candi, param_seasonal_candi, select_candi)
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:694.3874157603492
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:691.179761657701
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:490.93465236237415
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:490.84025213045544
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:685.7255423752355
# (1, 1, 0) (1, 1, 0, 12) 383.46119394314974

# %%
mod = sm.tsa.statespace.SARIMAX(
    df_out['out_count'],
    order=(1, 1, 0),
    seasonal_order=(1, 1, 0, 12),
    enforce_stationarity=True,
    enforce_invertibility=True
)

results = mod.fit()

print(results.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          out_count   No. Observations:                   42
# Model:             SARIMAX(1, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -188.731
# Date:                            Fri, 24 Dec 2021   AIC                            383.461
# Time:                                    14:57:41   BIC                            387.563
# Sample:                                         0   HQIC                           384.746
#                                              - 42
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3642      0.275      1.324      0.186      -0.175       0.904
# ar.S.L12      -0.7851      0.081     -9.659      0.000      -0.944      -0.626
# sigma2      1.794e+04   4708.325      3.811      0.000    8713.623    2.72e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.81
# Prob(Q):                              0.97   Prob(JB):                         0.67
# Heteroskedasticity (H):               1.13   Skew:                            -0.07
# Prob(H) (two-sided):                  0.85   Kurtosis:                         3.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
results.plot_diagnostics()
# results.plot_diagnostics(fig_size=(16,10))

# %% [markdown]
# ### get_prediction(dynamic=False)

# %%
pred = results.get_prediction(
    start=pd.to_datetime('2015-12-31'),
    dynamic=False
)

pred_ci = pred.conf_int()

# %%
# 관측 데이터  1980년 부터 끝까지 
ax = df_out['out_count']['1980' : ].plot( label='observed', figsize=(12, 8) )

# 예측
pred.predicted_mean.plot(
    ax=ax,
    label='One-step ahead Forecast',
    alpha=.7
)

ax.fill_between(
    pred_ci.index,
    pred_ci['lower out_count'],
    pred_ci['upper out_count'],
    color='k',
    alpha=.2
)

ax.set_xlabel('Date')
ax.set_ylabel('Count')
plt.legend(loc=1)

plt.show()

# %%
# Extract the predicted and true values of our time series
y_forecasted = pred_dynamic.predicted_mean
y_truth = df_out['out_count']['2021-11-30' : ]

# Compute the Mean Square Error
mse = (( y_forecasted - y_truth ) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format( round(mse, 2) ) )
# Out:
# The Mean Squared Error of our forecasts is 2491074.35

# %%
# Get forecast some steps ahead in future
pred_uc = results.get_forecast(steps=5 )

# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

# %%
# 관측 데이터  1980년 부터 끝까지 
ax = df_out['out_count']['1980' : ].plot( label='observed', figsize=(12, 8) )

# 예측
pred_uc.predicted_mean.plot(
    ax=ax,
    label='Forcast'
)

ax.fill_between(
    pred_ci.index,
    pred_ci.iloc[ :, 0 ],
    pred_ci.iloc[ :, 1 ],
    color='k',
    alpha=.2
)


ax.set_xlabel('Date')
ax.set_ylabel('Count')
plt.legend(loc=7)

plt.show()

# %%
model = ARIMA(df_out['out_count'], order = (2,1,2))
model_fit = model.fit(trend = 'c', full_output = True, disp = True)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.out_count   No. Observations:                   41
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -254.036
# Method:                       css-mle   S.D. of innovations            117.898
# Date:                Fri, 24 Dec 2021   AIC                            520.072
# Time:                        15:06:53   BIC                            530.354
# Sample:                             1   HQIC                           523.816
#
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                40.0680     35.421      1.131      0.258     -29.356     109.492
# ar.L1.D.out_count     0.0191      0.301      0.063      0.949      -0.571       0.610
# ar.L2.D.out_count     0.4365      0.188      2.324      0.020       0.068       0.805
# ma.L1.D.out_count     0.4630      0.292      1.583      0.113      -0.110       1.036
# ma.L2.D.out_count    -0.3865      0.238     -1.623      0.105      -0.853       0.080
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.4919           +0.0000j            1.4919            0.0000
# AR.2           -1.5356           +0.0000j            1.5356            0.5000
# MA.1           -1.1174           +0.0000j            1.1174            0.5000
# MA.2            2.3154           +0.0000j            2.3154            0.0000
# -----------------------------------------------------------------------------

# %%
fig = model_fit.plot_predict()

# %%
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
forecast_data = model_fit.forecast(steps=5)
forecast_data
# Out:
# (array([1811.85691313, 1840.59726514, 1859.8411738 , 1894.56692153,
#         1925.44312261]),
#  array([117.89764711, 210.79431352, 278.3098505 , 346.65107803,
#         405.39615561]),
#  array([[1580.78177093, 2042.93205533],
#         [1427.44800249, 2253.74652778],
#         [1314.36389028, 2405.31845732],
#         [1215.14329339, 2573.99054967],
#         [1130.88125815, 2720.00498707]]))

# %%
pred_y = forecast_data[0].tolist()

# %%
test_y = df_out['out_count']

# %%
pred_y_lower = []  # 마지막 5일의 예측 데이터 최소값
pred_y_upper = []  # 마지막 5일의 예측 데이터 최대값

# %%
for lower_upper in forecast_data[2]:
    lower = lower_upper[0]
    upper = lower_upper[1]
    pred_y_lower.append(lower)
    pred_y_upper.append(upper)

# %%
plt.plot(pred_y, color = 'gold') # 모델이 예측한 가격
plt.plot(test_y, color = 'green') # 실제가격
