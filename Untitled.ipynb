# %%
import pandas as pd
import numpy as np
import folium
import requests
import json
from folium.plugins import MarkerCluster

# %%
import warnings

# %%
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv("area_data.csv", encoding='cp949')
df
# Out:
#      area_type     code     area_name         lon        lat  area_store  \
# 0         골목상권  1000275        보문로26길  127.021354  37.587205    2.285714
# 1         골목상권  1000276        보문로31길  127.015681  37.588170    7.428571
# 2         발달상권  1001045  동작구 총신대입구역_1  126.980824  37.485978   16.428571
# 3         발달상권  1001046  서울 관악구 신림역_4  126.930214  37.486436   14.000000
# 4         발달상권  1001047       뱅뱅사거리_1  127.033469  37.488623   10.142857
# ...        ...      ...           ...         ...        ...         ...
# 1491      발달상권  1001153         당산역_1  126.899440  37.534401    2.857143
# 1492      발달상권  1001154     용산 전자상가_4  126.959834  37.535149    4.000000
# 1493      발달상권  1001155     용산 전자상가_5  126.964587  37.534646   10.714286
# 1494      발달상권  1001156    서울 강동구 길동역  127.138194  37.536030   11.428571
# 1495      발달상권  1001120     도산공원사거리_1  127.031153  37.520646   12.285714
#
#       area_sim_store  tot_customer      avg_take
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1496 entries, 0 to 1495
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   area_type       1496 non-null   object
#  1   code            1496 non-null   int64
#  2   area_name       1496 non-null   object
#  3   lon             1496 non-null   float64
#  4   lat             1496 non-null   float64
#  5   area_store      1496 non-null   float64
#  6   area_sim_store  1496 non-null   float64
#  7   tot_customer    1496 non-null   float64
#  8   avg_take        1496 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 105.3+ KB

# %%
# 서울 행정구역 json raw파일
r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

# %%
map =folium.Map(location=[37.5502, 126.982], zoom_start=11)
jsonData = json.loads(c)
folium.GeoJson(jsonData, name='seoul_geo').add_to(map)

for n in df.index:
    folium.CircleMarker([df['lat'][n], df['lon'][n]],
                        radius = 1,
                        color='red', fill_color='#ffee00').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import math

# %%
def calc_offsets(d, lat):
    return (
        abs(360*math.asin(math.sin(d/6371/2/1000)/math.cos(lat*math.pi/180))/math.pi),
        180*d/6371/1000/math.pi
    )

# %%
def radian(degree):
    return math.acos(-1)/180*degree

def coordinate_after_rotation(c, degree, offsets):
    return (
        c[0]+math.cos(radian(degree))*offsets[0],
        c[1]+math.sin(radian(degree))*offsets[1]
    )

# %%
c = df['lat'], df['lon']
c = (37.587205, 127.021354)
# 반경(meter)
d = 200
rotating_degree = 45

# %%
offsets = calc_offsets(d, c[1])
coordinates = [coordinate_after_rotation(c, d, offsets) for d in range(0, 360+1, rotating_degree)]

# %%
print(coordinates)
# Out:
# [(37.59019222052932, 127.021354), (37.58931728389318, 127.02262583281203), (37.587205, 127.02315264321184), (37.585092716106814, 127.02262583281203), (37.58421777947068, 127.021354), (37.585092716106814, 127.02008216718798), (37.587205, 127.01955535678816), (37.58931728389318, 127.02008216718798), (37.59019222052932, 127.021354)]

# %%
coordinates2 = []

for i in range(len(coordinates)):
    coordinates2.append(list(coordinates[i]))
    
coordinates2
# Out:
# [[37.59019222052932, 127.021354],
#  [37.58931728389318, 127.02262583281203],
#  [37.587205, 127.02315264321184],
#  [37.585092716106814, 127.02262583281203],
#  [37.58421777947068, 127.021354],
#  [37.585092716106814, 127.02008216718798],
#  [37.587205, 127.01955535678816],
#  [37.58931728389318, 127.02008216718798],
#  [37.59019222052932, 127.021354]]

# %%
_geojson = {
    'features': [
        {
            'type': 'Feature',
            'geometry': {
                'type': 'Polygon',
                'coordinates': [list(coordinates2)]
            },
        },
    ],
    'type': 'FeatureCollection'
}

# %%
_geojson
# Out:
# {'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[37.59019222052932, 127.021354],
#       [37.58931728389318, 127.02262583281203],
#       [37.587205, 127.02315264321184],
#       [37.585092716106814, 127.02262583281203],
#       [37.58421777947068, 127.021354],
#       [37.585092716106814, 127.02008216718798],
#       [37.587205, 127.01955535678816],
#       [37.58931728389318, 127.02008216718798],
#       [37.59019222052932, 127.021354]]]}}],
#  'type': 'FeatureCollection'}

# %%
c = _geojson.content
seoul_geo = json.load(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\TS17EF~1.SBY\AppData\Local\Temp/ipykernel_20436/1798480884.py in <module>
# ----> 1 c = _geojson.content
#       2 seoul_geo = json.load(c)
#
# AttributeError: 'dict' object has no attribute 'content'

# %%
map =folium.Map(location=[37.5502, 126.982], zoom_start=11)
jsonData = json.loads(c)
folium.GeoJson(jsonData, name='seoul_geo').add_to(map)

for n in df[0]:
    folium.CircleMarker([df['lat'][n], df['lon'][n]],
                        radius = 1,
                        color='red', fill_color='#ffee00').add_to(map)
map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\TS17EF~1.SBY\AppData\Local\Temp/ipykernel_20436/111184964.py in <module>
#       1 map =folium.Map(location=[37.5502, 126.982], zoom_start=11)
# ----> 2 jsonData = json.loads(c)
#       3 folium.GeoJson(jsonData, name='seoul_geo').add_to(map)
#       4
#       5 for n in df[0]:
#
# C:\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337     else:
#     338         if not isinstance(s, (bytes, bytearray)):
# --> 339             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                             f'not {s.__class__.__name__}')
#     341         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not tuple
